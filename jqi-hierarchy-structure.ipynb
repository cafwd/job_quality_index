# %% [markdown]
# # Create hierarchical structure for IPUMS and EDD data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
import warnings
from jqi_functions import *
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ## Creating CSV/dataframe

# %%
ca_ipums = cleaned_ipums('2019')

# %%
ca_ipums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 224526 entries, 0 to 224525
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YEAR              224526 non-null  int64
#  1   STATEFIP          224526 non-null  int64
#  2   COUNTYFIP         224526 non-null  int64
#  3   INDNAICS          224526 non-null  object
#  4   PERWT             224526 non-null  float64
#  5   INCWAGE           224526 non-null  int64
#  6   NAICS Code        224526 non-null  object
#  7   Industry Title_x  224526 non-null  object
#  8   Industry Title_y  224526 non-null  object
#  9   Main_Code         224526 non-null  int64
#  10  Sub_1_Code        224526 non-null  int64
#  11  Sub_2_Code        224526 non-null  object
#  12  Sub_3_Code        224526 non-null  object
#  13  Sub_4_Code        224526 non-null  object
# dtypes: float64(1), int64(6), object(7)
# memory usage: 25.7+ MB

# %%
county_info = pd.read_csv('data/county_to_regions_key - Sheet1.csv')

# %%
county_info.head()
# Out:
#    FIPS  COUNTYFIP        County       State             County, State  \
# 0  6001          1       Alameda  California       Alameda, California
# 1  6013         13  Contra Costa  California  Contra Costa, California
# 2  6095         95        Solano  California        Solano, California
# 3  6081         81     San Mateo  California     San Mateo, California
# 4  6085         85   Santa Clara  California   Santa Clara, California
#
#             EDD County                    Census County  \
# 0       Alameda County       Alameda County, California
# 1  Contra Costa County  Contra Costa County, California
# 2        Solano County        Solano County, California
# 3     San Mateo County     San Mateo County, California
# 4   Santa Clara County   Santa Clara County, California
#
#   Population - Households Rural/Urban Redstone Regions WF Regions CDI Regions  \
# 0                 383,468       Urban         Bay Area   Bay Area    Bay Area
# 1                 282,085       Urban         Bay Area   Bay Area    Bay Area
# 2                 107,267       Urban         Bay Area   Bay Area    Bay Area
# 3                 183,144       Urban         Bay Area   Bay Area    Bay Area
# 4                 456,440       Urban         Bay Area   Bay Area    Bay Area
#
#   Population
# 0  1,656,754
# 1  1,142,251
# 2    441,829
# 3    767,423
# 4  1,927,470

# %%
cost_of_living = pd.read_csv('data/united-way-col-1A1PS1C2019.csv') # 1 adult, 1 preschooler, 1 child

# %%
cost_of_living.head()
# Out:
#           Regions  Cost of Living
# 0        Bay Area           93392
# 1   Central Coast           76493
# 2  Central Valley           56747
# 3   Inland Empire           63170
# 4     Los Angeles           80216

# %%
ca_ipums = pd.merge(ca_ipums, county_info, on = 'COUNTYFIP')

# %%
ca_ipums = ca_ipums[['INDNAICS', 'PERWT', 'INCWAGE',
       'NAICS Code', 'Industry Title_x', 'Main_Code', 'Sub_1_Code', 'Sub_2_Code', 'Sub_3_Code', 'Sub_4_Code', 'County', 'Rural/Urban', 'CDI Regions']]

# %%
ca_ipums = pd.merge(ca_ipums, cost_of_living, left_on = 'CDI Regions', right_on = 'Regions')
ca_ipums = ca_ipums.rename(columns = {'Cost of Living':'Regional COL'})

# %%
ca_ipums = pd.merge(ca_ipums, cost_of_living, left_on = 'Rural/Urban', right_on = 'Regions')
ca_ipums = ca_ipums.rename(columns = {'Cost of Living':'Rural/Urban COL'})

# %%
ca_ipums = pd.merge(ca_ipums, cost_of_living, left_on = 'County', right_on = 'Regions')
ca_ipums = ca_ipums.rename(columns = {'Cost of Living':'County COL'})

# %%
ca_ipums = ca_ipums[['INDNAICS', 'PERWT', 'INCWAGE',
       'NAICS Code', 'Industry Title_x', 'Main_Code', 'Sub_1_Code', 'Sub_2_Code', 'Sub_3_Code', 'Sub_4_Code', 'County', 'Rural/Urban', 'CDI Regions',
                    'Regional COL', 'Rural/Urban COL', 'County COL']]

# %%
ca_ipums['Regional Rural/Urban'] = ca_ipums['CDI Regions'] + ' ' + ca_ipums['Rural/Urban']

# %%
ca_ipums = pd.merge(ca_ipums, cost_of_living, left_on = 'Regional Rural/Urban', right_on = 'Regions')
ca_ipums = ca_ipums.rename(columns = {'Cost of Living':'Regional Rural/Urban COL'})

# %%
ca_ipums = ca_ipums[['INDNAICS', 'PERWT', 'INCWAGE',
       'NAICS Code', 'Industry Title_x', 'Main_Code', 'Sub_1_Code', 'Sub_2_Code', 'Sub_3_Code',
       'Sub_4_Code', 'County', 'Rural/Urban', 'CDI Regions',
                    'Regional COL', 'Rural/Urban COL', 'County COL', 'Regional Rural/Urban COL']]

# %%
ca_ipums['Industry Title_x'] = normalize_titles(ca_ipums['Industry Title_x'])

# %%
ca_ipums
# Out:
#        INDNAICS  PERWT  INCWAGE NAICS Code  \
# 0          4853   21.0    23100       4853
# 1          4853   21.0    23100       4853
# 2          4853   21.0    23100       4853
# 3          4853   21.0    23100       4853
# 4          4853   11.0    28000       4853
# ...         ...    ...      ...        ...
# 488572     3113  558.0     5300       3113
# 488573     3113  244.0     5300       3113
# 488574     4247  117.0    50000       4247
# 488575    42491  148.0    40000      42491
# 488576     4245  130.0        0       4245
#
#                                          Industry Title_x  Main_Code  \
# 0                              taxi and limousine service        400
# 1                              taxi and limousine service        400
# 2                              taxi and limousine service        400
# 3                              taxi and limousine service        400
# 4                              taxi and limousine service        400
# ...                                                   ...        ...
# 488572                   sugar and confectionery products        300
# 488573                   sugar and confectionery products        300
# 488574  petroleum and petroleum products merchant whol...        400
# 488575                 farm supplies merchant wholesalers        400
# 488576    farm product raw materials merchant wholesalers        400
#
#         Sub_1_Code Sub_2_Code Sub_3_Code Sub_4_Code       County Rural/Urban  \
# 0              430        480        483        483  Los Angeles       Urban
# 1              430        480        483        483  Los Angeles       Urban
# 2              430        480        483        483  Los Angeles       Urban
# 3              430        480        483        483  Los Angeles       Urban
# 4              430        480        483        483  Los Angeles       Urban
# ...            ...        ...        ...        ...          ...         ...
# 488572         310        311        311        311     Humboldt       Rural
# 488573         310        311        311        311     Humboldt       Rural
# 488574         420        424       424d       424d     Humboldt       Rural
# 488575         420        424        424        424     Humboldt       Rural
# 488576         420        424        424        424     Humboldt       Rural
#
#           CDI Regions  Regional COL  Rural/Urban COL  County COL  \
# 0         Los Angeles         80216            79472       80216
# 1         Los Angeles         80216            79472       80216
# 2         Los Angeles         80216            79472       80216
# 3         Los Angeles         80216            79472       80216
# 4         Los Angeles         80216            79472       80216
# ...               ...           ...              ...         ...
# 488572  Redwood Coast         58625            58812       59608
# 488573  Redwood Coast         58625            58812       59608
# 488574  Redwood Coast         58625            58812       59608
# 488575  Redwood Coast         58625            58812       59608
# 488576  Redwood Coast         58625            58812       59608
#
#         Regional Rural/Urban COL
# 0                          80216
# 1                          80216
# 2                          80216
# 3                          80216
# 4                          80216
# ...                          ...
# 488572                     58625
# 488573                     58625
# 488574                     58625
# 488575                     58625
# 488576                     58625
#
# [488577 rows x 17 columns]

# %% [markdown]
# ## Merge with EDD Data

# %%
edd = pd.read_csv('data/edd_merged.csv')

# %%
edd['Area Name'] = edd['Area Name'].str.replace(' County', '')
edd = edd.loc[edd['Area Type'] == 'County']

# %%
edd.head()
# Out:
#   Industry Title LMID Industry Title Parsed_Code Area Type    Area Name  \
# 0         county              county         939    County       Madera
# 1         county              county         939    County       Fresno
# 2         county              county         939    County         Kern
# 3         county              county         939    County  Los Angeles
# 4         county              county         939    County       Madera
#
#      Date Seasonally Adjusted  Current Employment    Main_EDD  Main_Code  \
# 0  3/1/19                   N                1600  government        900
# 1  1/1/19                   N                7800  government        900
# 2  1/1/19                   N                9900  government        900
# 3  1/1/19                   N              106800  government        900
# 4  1/1/19                   N                1600  government        900
#
#                         Sub_1  Sub_1_Code             Sub_2 Sub_2_Code  \
# 0  state and local government         940  local government        930
# 1  state and local government         940  local government        930
# 2  state and local government         940  local government        930
# 3  state and local government         940  local government        930
# 4  state and local government         940  local government        930
#
#                                   Sub_3 Sub_3_Code   Sub_4 Sub_4_Code
# 0  local government excluding education        932  county        939
# 1  local government excluding education        932  county        939
# 2  local government excluding education        932  county        939
# 3  local government excluding education        932  county        939
# 4  local government excluding education        932  county        939

# %%
ca_ipums_edd = pd.merge(ca_ipums, edd, left_on=['County', 'Industry Title_x'], right_on=['Area Name', 'Sub_4'])

# %%
ca_ipums_edd.head().T
# Out:
#                                                                   0  \
# INDNAICS                                                       5241
# PERWT                                                          36.0
# INCWAGE                                                      110000
# NAICS Code                                                     5241
# Industry Title_x                                 insurance carriers
# Main_Code_x                                                     520
# Sub_1_Code_x                                                    521
# Sub_2_Code_x                                                    524
# Sub_3_Code_x                                                   524a
# Sub_4_Code_x                                                   524a
# County                                                  Los Angeles
# Rural/Urban                                                   Urban
# CDI Regions                                             Los Angeles
# Regional COL                                                  80216
# Rural/Urban COL                                               79472
# County COL                                                    80216
# Regional Rural/Urban COL                                      80216
# Industry Title                                   insurance carriers
# LMID Industry Title                              insurance carriers
# Parsed_Code                                                    524a
# Area Type                                                    County
# Area Name                                               Los Angeles
# Date                                                         1/1/19
# Seasonally Adjusted                                               N
# Current Employment                                            20600
# Main_EDD                                       financial activities
# Main_Code_y                                                     520
# Sub_1                                         finance and insurance
# Sub_1_Code_y                                                    521
# Sub_2                     insurance carriers and related activities
# Sub_2_Code_y                                                    524
# Sub_3                                            insurance carriers
# Sub_3_Code_y                                                   524a
# Sub_4                                            insurance carriers
# Sub_4_Code_y                                                   524a
#
#                                                                   1  \
# INDNAICS                                                       5241
# PERWT                                                          36.0
# INCWAGE                                                      110000
# NAICS Code                                                     5241
# Industry Title_x                                 insurance carriers
# Main_Code_x                                                     520
# Sub_1_Code_x                                                    521
# Sub_2_Code_x                                                    524
# Sub_3_Code_x                                                   524a
# Sub_4_Code_x                                                   524a
# County                                                  Los Angeles
# Rural/Urban                                                   Urban
# CDI Regions                                             Los Angeles
# Regional COL                                                  80216
# Rural/Urban COL                                               79472
# County COL                                                    80216
# Regional Rural/Urban COL                                      80216
# Industry Title                                   insurance carriers
# LMID Industry Title                              insurance carriers
# Parsed_Code                                                    524a
# Area Type                                                    County
# Area Name                                               Los Angeles
# Date                                                         2/1/19
# Seasonally Adjusted                                               N
# Current Employment                                            20500
# Main_EDD                                       financial activities
# Main_Code_y                                                     520
# Sub_1                                         finance and insurance
# Sub_1_Code_y                                                    521
# Sub_2                     insurance carriers and related activities
# Sub_2_Code_y                                                    524
# Sub_3                                            insurance carriers
# Sub_3_Code_y                                                   524a
# Sub_4                                            insurance carriers
# Sub_4_Code_y                                                   524a
#
#                                                                   2  \
# INDNAICS                                                       5241
# PERWT                                                          36.0
# INCWAGE                                                      110000
# NAICS Code                                                     5241
# Industry Title_x                                 insurance carriers
# Main_Code_x                                                     520
# Sub_1_Code_x                                                    521
# Sub_2_Code_x                                                    524
# Sub_3_Code_x                                                   524a
# Sub_4_Code_x                                                   524a
# County                                                  Los Angeles
# Rural/Urban                                                   Urban
# CDI Regions                                             Los Angeles
# Regional COL                                                  80216
# Rural/Urban COL                                               79472
# County COL                                                    80216
# Regional Rural/Urban COL                                      80216
# Industry Title                                   insurance carriers
# LMID Industry Title                              insurance carriers
# Parsed_Code                                                    524a
# Area Type                                                    County
# Area Name                                               Los Angeles
# Date                                                         3/1/19
# Seasonally Adjusted                                               N
# Current Employment                                            20800
# Main_EDD                                       financial activities
# Main_Code_y                                                     520
# Sub_1                                         finance and insurance
# Sub_1_Code_y                                                    521
# Sub_2                     insurance carriers and related activities
# Sub_2_Code_y                                                    524
# Sub_3                                            insurance carriers
# Sub_3_Code_y                                                   524a
# Sub_4                                            insurance carriers
# Sub_4_Code_y                                                   524a
#
#                                                                   3  \
# INDNAICS                                                       5241
# PERWT                                                          36.0
# INCWAGE                                                      110000
# NAICS Code                                                     5241
# Industry Title_x                                 insurance carriers
# Main_Code_x                                                     520
# Sub_1_Code_x                                                    521
# Sub_2_Code_x                                                    524
# Sub_3_Code_x                                                   524a
# Sub_4_Code_x                                                   524a
# County                                                  Los Angeles
# Rural/Urban                                                   Urban
# CDI Regions                                             Los Angeles
# Regional COL                                                  80216
# Rural/Urban COL                                               79472
# County COL                                                    80216
# Regional Rural/Urban COL                                      80216
# Industry Title                                   insurance carriers
# LMID Industry Title                              insurance carriers
# Parsed_Code                                                    524a
# Area Type                                                    County
# Area Name                                               Los Angeles
# Date                                                         4/1/19
# Seasonally Adjusted                                               N
# Current Employment                                            20800
# Main_EDD                                       financial activities
# Main_Code_y                                                     520
# Sub_1                                         finance and insurance
# Sub_1_Code_y                                                    521
# Sub_2                     insurance carriers and related activities
# Sub_2_Code_y                                                    524
# Sub_3                                            insurance carriers
# Sub_3_Code_y                                                   524a
# Sub_4                                            insurance carriers
# Sub_4_Code_y                                                   524a
#
#                                                                   4
# INDNAICS                                                       5241
# PERWT                                                          36.0
# INCWAGE                                                      110000
# NAICS Code                                                     5241
# Industry Title_x                                 insurance carriers
# Main_Code_x                                                     520
# Sub_1_Code_x                                                    521
# Sub_2_Code_x                                                    524
# Sub_3_Code_x                                                   524a
# Sub_4_Code_x                                                   524a
# County                                                  Los Angeles
# Rural/Urban                                                   Urban
# CDI Regions                                             Los Angeles
# Regional COL                                                  80216
# Rural/Urban COL                                               79472
# County COL                                                    80216
# Regional Rural/Urban COL                                      80216
# Industry Title                                   insurance carriers
# LMID Industry Title                              insurance carriers
# Parsed_Code                                                    524a
# Area Type                                                    County
# Area Name                                               Los Angeles
# Date                                                         5/1/19
# Seasonally Adjusted                                               N
# Current Employment                                            20700
# Main_EDD                                       financial activities
# Main_Code_y                                                     520
# Sub_1                                         finance and insurance
# Sub_1_Code_y                                                    521
# Sub_2                     insurance carriers and related activities
# Sub_2_Code_y                                                    524
# Sub_3                                            insurance carriers
# Sub_3_Code_y                                                   524a
# Sub_4                                            insurance carriers
# Sub_4_Code_y                                                   524a

# %%
ca_ipums_edd.columns.values
# Out:
# array(['INDNAICS', 'PERWT', 'INCWAGE', 'NAICS Code', 'Industry Title_x',
#        'Main_Code_x', 'Sub_1_Code_x', 'Sub_2_Code_x', 'Sub_3_Code_x',
#        'Sub_4_Code_x', 'County', 'Rural/Urban', 'CDI Regions',
#        'Regional COL', 'Rural/Urban COL', 'County COL',
#        'Regional Rural/Urban COL', 'Industry Title',
#        'LMID Industry Title', 'Parsed_Code', 'Area Type', 'Area Name',
#        'Date', 'Seasonally Adjusted', 'Current Employment', 'Main_EDD',
#        'Main_Code_y', 'Sub_1', 'Sub_1_Code_y', 'Sub_2', 'Sub_2_Code_y',
#        'Sub_3', 'Sub_3_Code_y', 'Sub_4', 'Sub_4_Code_y'], dtype=object)

# %%
ca_ipums_edd = ca_ipums_edd[['INDNAICS', 'PERWT', 'INCWAGE', 'NAICS Code',
                            'County', 'Rural/Urban', 'CDI Regions',
                           'Regional COL', 'Rural/Urban COL', 'County COL',
                           'Regional Rural/Urban COL', 'LMID Industry Title', 'Area Type',
                           'Date', 'Seasonally Adjusted', 'Current Employment', 'Main_EDD',
                           'Main_Code_y', 'Sub_1', 'Sub_1_Code_y', 'Sub_2', 'Sub_2_Code_y',
                           'Sub_3', 'Sub_3_Code_y', 'Sub_4', 'Sub_4_Code_y']]

# %%
ca_ipums_edd = ca_ipums_edd.rename(columns={"Main_Code_y": "Main_Code",
                                           "Sub_1_Code_y": "Sub_1_Code",
                                           "Sub_2_Code_y": "Sub_2_Code",
                                           "Sub_3_Code_y": "Sub_3_Code",
                                           "Sub_4_Code_y": "Sub_4_Code"})

# %%
ca_ipums_edd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 741060 entries, 0 to 741059
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   INDNAICS                  741060 non-null  object
#  1   PERWT                     741060 non-null  float64
#  2   INCWAGE                   741060 non-null  int64
#  3   NAICS Code                741060 non-null  object
#  4   County                    741060 non-null  object
#  5   Rural/Urban               741060 non-null  object
#  6   CDI Regions               741060 non-null  object
#  7   Regional COL              741060 non-null  int64
#  8   Rural/Urban COL           741060 non-null  int64
#  9   County COL                741060 non-null  int64
#  10  Regional Rural/Urban COL  741060 non-null  int64
#  11  LMID Industry Title       741060 non-null  object
#  12  Area Type                 741060 non-null  object
#  13  Date                      741060 non-null  object
#  14  Seasonally Adjusted       741060 non-null  object
#  15  Current Employment        741060 non-null  int64
#  16  Main_EDD                  741060 non-null  object
#  17  Main_Code                 741060 non-null  int64
#  18  Sub_1                     741060 non-null  object
#  19  Sub_1_Code                741060 non-null  int64
#  20  Sub_2                     741060 non-null  object
#  21  Sub_2_Code                741060 non-null  object
#  22  Sub_3                     741060 non-null  object
#  23  Sub_3_Code                741060 non-null  object
#  24  Sub_4                     741060 non-null  object
#  25  Sub_4_Code                741060 non-null  object
# dtypes: float64(1), int64(8), object(17)
# memory usage: 152.7+ MB

# %%
# ca_ipums_edd.to_csv('data/ca_ipums_full_hierarchy.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Checking what industries from original EDD data were dropped

# %%
edd_antijoin = edd[~edd['LMID Industry Title'].isin(ca_ipums_edd['Sub_4'].unique())]

# %%
len(edd_antijoin)
# Out:
# 3144

# %%
edd_antijoin['LMID Industry Title'].unique()
# Out:
# array(['county', 'total farm', 'state government education', 'city',
#        'local government education', 'general merchandise stores',
#        'state government excluding education', 'department of defense',
#        'federal government excluding department of defense',
#        'building foundation and exterior contractors',
#        'residential building construction',
#        'building finishing contractors',
#        'travel arrangement and reservation services',
#        'health and personal care stores',
#        'bakeries and tortilla manufacturing',
#        'primary metal manufacturing', 'lessors of real estate',
#        'prof and commercial equip merchant wholesalers',
#        'mgmt scientific and technical consulting services',
#        'transit and ground passenger transportation',
#        'limitedservice eating places', 'grocery stores',
#        'sporting goods hobby and musical instrument store',
#        'textile mills', 'offices of real estate agents and brokers',
#        'agencies broker and other insurance related act',
#        'cable and other subscription programming',
#        'building equipment contractors',
#        'auto parts accessories and tire stores',
#        'misc nondurable goods merchant wholesalers',
#        'grocery and related products merchant wholesalers',
#        'household and institutional furniture mfg',
#        'aerospace product and parts manufacturing',
#        'electronic instrument manufacturing', 'fullservice restaurants',
#        'other amusement and recreation industries', 'gambling industries',
#        'museums historical sites and similar institutions',
#        'newspaper periodical book and directory publishers',
#        'pharmaceutical and medicine manufacturing',
#        'machinery equip and supplies merchant wholesalers',
#        'nonresidential building construction',
#        'activities related to credit intermediation',
#        'nondepository credit intermediation',
#        'depository credit intermediation',
#        'accounting tax preparation and bookkeeping services',
#        'activities related to real estate',
#        'colleges universities and professional schools',
#        'services to buildings and dwellings',
#        'book periodical and music stores',
#        'petroleum and coal products manufacturing',
#        'cut and sew apparel manufacturing', 'dairy product manufacturing',
#        'electrical equipment and appliance manufacturing',
#        'other specialty trade contractors', 'nursing care facilities',
#        'special food services', 'accommodation',
#        'plastics and rubber products manufacturing',
#        'motor vehicle and parts merchant wholesalers',
#        'apparel piece goods and notions merch wholesalers',
#        'electrical and electronic goods merch wholesalers',
#        'electronics and appliance stores',
#        'wholesalers electronic markets agents and brokers',
#        'advertising and related services',
#        'radio and television broadcasting',
#        'beverage and tobacco product manufacturing'], dtype=object)

# %% [markdown]
# ## Attempting sample size function

# %%
ca_ipums_edd.head().T
# Out:
#                                                                   0  \
# INDNAICS                                                       5241
# PERWT                                                          36.0
# INCWAGE                                                      110000
# NAICS Code                                                     5241
# County                                                  Los Angeles
# Rural/Urban                                                   Urban
# CDI Regions                                             Los Angeles
# Regional COL                                                  80216
# Rural/Urban COL                                               79472
# County COL                                                    80216
# Regional Rural/Urban COL                                      80216
# LMID Industry Title                              insurance carriers
# Area Type                                                    County
# Date                                                         1/1/19
# Seasonally Adjusted                                               N
# Current Employment                                            20600
# Main_EDD                                       financial activities
# Main_Code                                                       520
# Sub_1                                         finance and insurance
# Sub_1_Code                                                      521
# Sub_2                     insurance carriers and related activities
# Sub_2_Code                                                      524
# Sub_3                                            insurance carriers
# Sub_3_Code                                                     524a
# Sub_4                                            insurance carriers
# Sub_4_Code                                                     524a
#
#                                                                   1  \
# INDNAICS                                                       5241
# PERWT                                                          36.0
# INCWAGE                                                      110000
# NAICS Code                                                     5241
# County                                                  Los Angeles
# Rural/Urban                                                   Urban
# CDI Regions                                             Los Angeles
# Regional COL                                                  80216
# Rural/Urban COL                                               79472
# County COL                                                    80216
# Regional Rural/Urban COL                                      80216
# LMID Industry Title                              insurance carriers
# Area Type                                                    County
# Date                                                         2/1/19
# Seasonally Adjusted                                               N
# Current Employment                                            20500
# Main_EDD                                       financial activities
# Main_Code                                                       520
# Sub_1                                         finance and insurance
# Sub_1_Code                                                      521
# Sub_2                     insurance carriers and related activities
# Sub_2_Code                                                      524
# Sub_3                                            insurance carriers
# Sub_3_Code                                                     524a
# Sub_4                                            insurance carriers
# Sub_4_Code                                                     524a
#
#                                                                   2  \
# INDNAICS                                                       5241
# PERWT                                                          36.0
# INCWAGE                                                      110000
# NAICS Code                                                     5241
# County                                                  Los Angeles
# Rural/Urban                                                   Urban
# CDI Regions                                             Los Angeles
# Regional COL                                                  80216
# Rural/Urban COL                                               79472
# County COL                                                    80216
# Regional Rural/Urban COL                                      80216
# LMID Industry Title                              insurance carriers
# Area Type                                                    County
# Date                                                         3/1/19
# Seasonally Adjusted                                               N
# Current Employment                                            20800
# Main_EDD                                       financial activities
# Main_Code                                                       520
# Sub_1                                         finance and insurance
# Sub_1_Code                                                      521
# Sub_2                     insurance carriers and related activities
# Sub_2_Code                                                      524
# Sub_3                                            insurance carriers
# Sub_3_Code                                                     524a
# Sub_4                                            insurance carriers
# Sub_4_Code                                                     524a
#
#                                                                   3  \
# INDNAICS                                                       5241
# PERWT                                                          36.0
# INCWAGE                                                      110000
# NAICS Code                                                     5241
# County                                                  Los Angeles
# Rural/Urban                                                   Urban
# CDI Regions                                             Los Angeles
# Regional COL                                                  80216
# Rural/Urban COL                                               79472
# County COL                                                    80216
# Regional Rural/Urban COL                                      80216
# LMID Industry Title                              insurance carriers
# Area Type                                                    County
# Date                                                         4/1/19
# Seasonally Adjusted                                               N
# Current Employment                                            20800
# Main_EDD                                       financial activities
# Main_Code                                                       520
# Sub_1                                         finance and insurance
# Sub_1_Code                                                      521
# Sub_2                     insurance carriers and related activities
# Sub_2_Code                                                      524
# Sub_3                                            insurance carriers
# Sub_3_Code                                                     524a
# Sub_4                                            insurance carriers
# Sub_4_Code                                                     524a
#
#                                                                   4
# INDNAICS                                                       5241
# PERWT                                                          36.0
# INCWAGE                                                      110000
# NAICS Code                                                     5241
# County                                                  Los Angeles
# Rural/Urban                                                   Urban
# CDI Regions                                             Los Angeles
# Regional COL                                                  80216
# Rural/Urban COL                                               79472
# County COL                                                    80216
# Regional Rural/Urban COL                                      80216
# LMID Industry Title                              insurance carriers
# Area Type                                                    County
# Date                                                         5/1/19
# Seasonally Adjusted                                               N
# Current Employment                                            20700
# Main_EDD                                       financial activities
# Main_Code                                                       520
# Sub_1                                         finance and insurance
# Sub_1_Code                                                      521
# Sub_2                     insurance carriers and related activities
# Sub_2_Code                                                      524
# Sub_3                                            insurance carriers
# Sub_3_Code                                                     524a
# Sub_4                                            insurance carriers
# Sub_4_Code                                                     524a

# %%
def add_to_state_df(df):
    df['Above CA Threshold'] = df['INCWAGE'] > 74448
    df['wt_ind_counts'] = df['PERWT'].groupby(df['INDNAICS']).transform('sum')
    df["Above CA Threshold"] = df["Above CA Threshold"].astype(int)
    df["wt_CA_above_thresh"] = df["Above CA Threshold"] * df['PERWT']
    df['wt_CA_high_wage_count'] = df['wt_CA_above_thresh'].groupby(
        df['INDNAICS']).transform('sum')
    df['wt_CA_high_wage_perc'] = (df['wt_CA_high_wage_count'] / df['wt_ind_counts']) * 100
    df['unwt_ind_counts'] = df['INDNAICS'].groupby(df['INDNAICS']).transform('count')
    return df

# %% [markdown]
# #### Rural/Urban level

# %%
def add_to_community_df(df):
    df['above_comm_thresh'] = df['INCWAGE'] > df['Rural/Urban COL']
    df_agg = df.groupby(['INDNAICS','Rural/Urban']).agg(wt_comm_ind_counts = ('PERWT','sum')).reset_index()
    df = pd.merge(df, df_agg, on='INDNAICS')
    df["above_comm_thresh"] = df["above_comm_thresh"].astype(int)
    df["wt_comm_above_thresh"] = df["above_comm_thresh"] * df['PERWT']
    df_agg = df.groupby(['INDNAICS','Rural/Urban_x']).agg(wt_comm_high_wage_count = ('wt_comm_above_thresh','sum')).reset_index()
    df = pd.merge(df, df_agg, on='INDNAICS')
    df['wt_comm_high_wage_perc'] = (df['wt_comm_high_wage_count'] / df['wt_comm_ind_counts']) * 100
    df_agg = df.groupby(['INDNAICS','Rural/Urban_x_x']).agg(unwt_comm_ind_counts = ('INDNAICS','count')).reset_index()
    df = pd.merge(df, df_agg, on='INDNAICS')
    return df

# %% [markdown]
# #### Regional Level

# %%
def add_to_region_df(df):
    df['above_region_thresh'] = df['INCWAGE'] > df['Regional COL']
    df_agg = df.groupby(['INDNAICS','CDI Regions']).agg(wt_reg_ind_counts = ('PERWT','sum')).reset_index()
    df = pd.merge(df, df_agg, on='INDNAICS')
    df["above_region_thresh"] = df["above_region_thresh"].astype(int)
    df["wt_reg_above_thresh"] = df["above_region_thresh"] * df['PERWT']
    df_agg = df.groupby(['INDNAICS','CDI Regions_x']).agg(wt_reg_high_wage_count = ('wt_reg_above_thresh','sum')).reset_index()
    df = pd.merge(df, df_agg, on='INDNAICS')
    df['wt_reg_high_wage_perc'] = (df['wt_reg_high_wage_count'] / df['wt_reg_ind_counts']) * 100
    df_agg = df.groupby(['INDNAICS','CDI Regions_x_x']).agg(unwt_comm_ind_counts = ('INDNAICS','count')).reset_index()
    df = pd.merge(df, df_agg, on='INDNAICS')
    return df

# %% [markdown]
# #### Regional Rural/Urban Level

# %%
def add_to_regioncomm_df(df):
    df['above_regcomm_thresh'] = df['INCWAGE'] > df['Regional Rural/Urban COL']
    df['wt_regcomm_ind_counts'] = df['PERWT'].groupby(df['INDNAICS']).transform('sum')
    df["above_regcomm_thresh"] = df["above_regcomm_thresh"].astype(int)
    df["wt_regcomm_above_thresh"] = df["above_regcomm_thresh"] * df['PERWT']
    df['wt_regcomm_hw_count'] = df['wt_regcomm_above_thresh'].groupby(
        df['INDNAICS']).transform('sum')
    df['wt_regcomm_hw_perc'] = (df['wt_regcomm_hw_count'] / df['wt_regcomm_ind_counts']) * 100
    df['unwt_regcomm_ind_counts'] = df['INDNAICS'].groupby(df['INDNAICS']).transform('count')
    return df

# %% [markdown]
# #### County Level

# %%
def add_to_county_df(df):
    df['above_county_thresh'] = df['INCWAGE'] > df['County COL']
    df['wt_county_ind_counts'] = df['PERWT'].groupby(df['INDNAICS']).transform('sum')
    df["above_county_thresh"] = df["above_county_thresh"].astype(int)
    df["wt_county_above_thresh"] = df["above_county_thresh"] * df['PERWT']
    df['wt_county_hw_count'] = df['wt_county_above_thresh'].groupby(
        df['INDNAICS']).transform('sum')
    df['wt_county_hw_perc'] = (df['wt_county_hw_count'] / df['wt_county_ind_counts']) * 100
    df['unwt_county_ind_counts'] = df['INDNAICS'].groupby(df['INDNAICS']).transform('count')
    return df

# %%
def add_geo_high_wages(df): # need to fix - giving same numbers for each geo level
    df_new = df.copy()
    # creating state level counts
    df_new = add_to_state_df(df_new)
    
    # creating rural/urban level counts
    df_new = add_to_community_df(df_new)
    
    # creating regional level counts
    df_new = add_to_region_df(df_new)
    
    # creating regional rural/urban level counts
    df_new = add_to_regioncomm_df(df_new)
    
    # creating county level counts
    df_new = add_to_county_df(df_new)
    
    # filter out dead columns
    pass
    return df_new

# %%
ca_ipums_edd_hw = add_geo_high_wages(ca_ipums_edd)

# %%
ca_ipums_edd_hw.tail().T
# Out:
#                                                        44796631  \
# INDNAICS                                                   5112
# PERWT                                                     105.0
# INCWAGE                                                  200000
# NAICS Code                                                 5112
# County                                                San Diego
# Rural/Urban_x_x_x                                         Urban
# CDI Regions_x_x_x                            San Diego-Imperial
# Regional COL                                              51652
# Rural/Urban COL                                           79472
# County COL                                                79472
# Regional Rural/Urban COL                                  79472
# LMID Industry Title                         software publishers
# Area Type                                                County
# Date                                                     8/1/19
# Seasonally Adjusted                                           N
# Current Employment                                         5400
# Main_EDD                                            information
# Main_Code                                                   500
# Sub_1                     publishing industries except internet
# Sub_1_Code                                                  511
# Sub_2                                       software publishers
# Sub_2_Code                                                 511b
# Sub_3                                       software publishers
# Sub_3_Code                                                 511b
# Sub_4                                       software publishers
# Sub_4_Code                                                 511b
# Above CA Threshold                                            1
# wt_ind_counts                                           26136.0
# wt_CA_above_thresh                                        105.0
# wt_CA_high_wage_count                                   21240.0
# wt_CA_high_wage_perc                                  81.267218
# unwt_ind_counts                                             276
# above_comm_thresh                                             1
# Rural/Urban_y                                             Urban
# wt_comm_ind_counts                                      26136.0
# wt_comm_above_thresh                                      105.0
# Rural/Urban_x_y                                           Urban
# wt_comm_high_wage_count                                 21240.0
# wt_comm_high_wage_perc                                81.267218
# Rural/Urban_x_x_y                                         Urban
# unwt_comm_ind_counts_x                                      276
# above_region_thresh                                           1
# CDI Regions_y                                San Diego-Imperial
# wt_reg_ind_counts                                       26136.0
# wt_reg_above_thresh                                       105.0
# CDI Regions_x_y                              San Diego-Imperial
# wt_reg_high_wage_count                                  21804.0
# wt_reg_high_wage_perc                                 83.425161
# CDI Regions_x_x_y                            San Diego-Imperial
# unwt_comm_ind_counts_y                                      276
# above_regcomm_thresh                                          1
# wt_regcomm_ind_counts                                   26136.0
# wt_regcomm_above_thresh                                   105.0
# wt_regcomm_hw_count                                     21240.0
# wt_regcomm_hw_perc                                    81.267218
# unwt_regcomm_ind_counts                                     276
# above_county_thresh                                           1
# wt_county_ind_counts                                    26136.0
# wt_county_above_thresh                                    105.0
# wt_county_hw_count                                      21240.0
# wt_county_hw_perc                                     81.267218
# unwt_county_ind_counts                                      276
#
#                                                        44796632  \
# INDNAICS                                                   5112
# PERWT                                                     105.0
# INCWAGE                                                  200000
# NAICS Code                                                 5112
# County                                                San Diego
# Rural/Urban_x_x_x                                         Urban
# CDI Regions_x_x_x                            San Diego-Imperial
# Regional COL                                              51652
# Rural/Urban COL                                           79472
# County COL                                                79472
# Regional Rural/Urban COL                                  79472
# LMID Industry Title                         software publishers
# Area Type                                                County
# Date                                                     9/1/19
# Seasonally Adjusted                                           N
# Current Employment                                         5400
# Main_EDD                                            information
# Main_Code                                                   500
# Sub_1                     publishing industries except internet
# Sub_1_Code                                                  511
# Sub_2                                       software publishers
# Sub_2_Code                                                 511b
# Sub_3                                       software publishers
# Sub_3_Code                                                 511b
# Sub_4                                       software publishers
# Sub_4_Code                                                 511b
# Above CA Threshold                                            1
# wt_ind_counts                                           26136.0
# wt_CA_above_thresh                                        105.0
# wt_CA_high_wage_count                                   21240.0
# wt_CA_high_wage_perc                                  81.267218
# unwt_ind_counts                                             276
# above_comm_thresh                                             1
# Rural/Urban_y                                             Urban
# wt_comm_ind_counts                                      26136.0
# wt_comm_above_thresh                                      105.0
# Rural/Urban_x_y                                           Urban
# wt_comm_high_wage_count                                 21240.0
# wt_comm_high_wage_perc                                81.267218
# Rural/Urban_x_x_y                                         Urban
# unwt_comm_ind_counts_x                                      276
# above_region_thresh                                           1
# CDI Regions_y                                San Diego-Imperial
# wt_reg_ind_counts                                       26136.0
# wt_reg_above_thresh                                       105.0
# CDI Regions_x_y                              San Diego-Imperial
# wt_reg_high_wage_count                                  21804.0
# wt_reg_high_wage_perc                                 83.425161
# CDI Regions_x_x_y                            San Diego-Imperial
# unwt_comm_ind_counts_y                                      276
# above_regcomm_thresh                                          1
# wt_regcomm_ind_counts                                   26136.0
# wt_regcomm_above_thresh                                   105.0
# wt_regcomm_hw_count                                     21240.0
# wt_regcomm_hw_perc                                    81.267218
# unwt_regcomm_ind_counts                                     276
# above_county_thresh                                           1
# wt_county_ind_counts                                    26136.0
# wt_county_above_thresh                                    105.0
# wt_county_hw_count                                      21240.0
# wt_county_hw_perc                                     81.267218
# unwt_county_ind_counts                                      276
#
#                                                        44796633  \
# INDNAICS                                                   5112
# PERWT                                                     105.0
# INCWAGE                                                  200000
# NAICS Code                                                 5112
# County                                                San Diego
# Rural/Urban_x_x_x                                         Urban
# CDI Regions_x_x_x                            San Diego-Imperial
# Regional COL                                              51652
# Rural/Urban COL                                           79472
# County COL                                                79472
# Regional Rural/Urban COL                                  79472
# LMID Industry Title                         software publishers
# Area Type                                                County
# Date                                                    10/1/19
# Seasonally Adjusted                                           N
# Current Employment                                         5300
# Main_EDD                                            information
# Main_Code                                                   500
# Sub_1                     publishing industries except internet
# Sub_1_Code                                                  511
# Sub_2                                       software publishers
# Sub_2_Code                                                 511b
# Sub_3                                       software publishers
# Sub_3_Code                                                 511b
# Sub_4                                       software publishers
# Sub_4_Code                                                 511b
# Above CA Threshold                                            1
# wt_ind_counts                                           26136.0
# wt_CA_above_thresh                                        105.0
# wt_CA_high_wage_count                                   21240.0
# wt_CA_high_wage_perc                                  81.267218
# unwt_ind_counts                                             276
# above_comm_thresh                                             1
# Rural/Urban_y                                             Urban
# wt_comm_ind_counts                                      26136.0
# wt_comm_above_thresh                                      105.0
# Rural/Urban_x_y                                           Urban
# wt_comm_high_wage_count                                 21240.0
# wt_comm_high_wage_perc                                81.267218
# Rural/Urban_x_x_y                                         Urban
# unwt_comm_ind_counts_x                                      276
# above_region_thresh                                           1
# CDI Regions_y                                San Diego-Imperial
# wt_reg_ind_counts                                       26136.0
# wt_reg_above_thresh                                       105.0
# CDI Regions_x_y                              San Diego-Imperial
# wt_reg_high_wage_count                                  21804.0
# wt_reg_high_wage_perc                                 83.425161
# CDI Regions_x_x_y                            San Diego-Imperial
# unwt_comm_ind_counts_y                                      276
# above_regcomm_thresh                                          1
# wt_regcomm_ind_counts                                   26136.0
# wt_regcomm_above_thresh                                   105.0
# wt_regcomm_hw_count                                     21240.0
# wt_regcomm_hw_perc                                    81.267218
# unwt_regcomm_ind_counts                                     276
# above_county_thresh                                           1
# wt_county_ind_counts                                    26136.0
# wt_county_above_thresh                                    105.0
# wt_county_hw_count                                      21240.0
# wt_county_hw_perc                                     81.267218
# unwt_county_ind_counts                                      276
#
#                                                        44796634  \
# INDNAICS                                                   5112
# PERWT                                                     105.0
# INCWAGE                                                  200000
# NAICS Code                                                 5112
# County                                                San Diego
# Rural/Urban_x_x_x                                         Urban
# CDI Regions_x_x_x                            San Diego-Imperial
# Regional COL                                              51652
# Rural/Urban COL                                           79472
# County COL                                                79472
# Regional Rural/Urban COL                                  79472
# LMID Industry Title                         software publishers
# Area Type                                                County
# Date                                                    11/1/19
# Seasonally Adjusted                                           N
# Current Employment                                         5400
# Main_EDD                                            information
# Main_Code                                                   500
# Sub_1                     publishing industries except internet
# Sub_1_Code                                                  511
# Sub_2                                       software publishers
# Sub_2_Code                                                 511b
# Sub_3                                       software publishers
# Sub_3_Code                                                 511b
# Sub_4                                       software publishers
# Sub_4_Code                                                 511b
# Above CA Threshold                                            1
# wt_ind_counts                                           26136.0
# wt_CA_above_thresh                                        105.0
# wt_CA_high_wage_count                                   21240.0
# wt_CA_high_wage_perc                                  81.267218
# unwt_ind_counts                                             276
# above_comm_thresh                                             1
# Rural/Urban_y                                             Urban
# wt_comm_ind_counts                                      26136.0
# wt_comm_above_thresh                                      105.0
# Rural/Urban_x_y                                           Urban
# wt_comm_high_wage_count                                 21240.0
# wt_comm_high_wage_perc                                81.267218
# Rural/Urban_x_x_y                                         Urban
# unwt_comm_ind_counts_x                                      276
# above_region_thresh                                           1
# CDI Regions_y                                San Diego-Imperial
# wt_reg_ind_counts                                       26136.0
# wt_reg_above_thresh                                       105.0
# CDI Regions_x_y                              San Diego-Imperial
# wt_reg_high_wage_count                                  21804.0
# wt_reg_high_wage_perc                                 83.425161
# CDI Regions_x_x_y                            San Diego-Imperial
# unwt_comm_ind_counts_y                                      276
# above_regcomm_thresh                                          1
# wt_regcomm_ind_counts                                   26136.0
# wt_regcomm_above_thresh                                   105.0
# wt_regcomm_hw_count                                     21240.0
# wt_regcomm_hw_perc                                    81.267218
# unwt_regcomm_ind_counts                                     276
# above_county_thresh                                           1
# wt_county_ind_counts                                    26136.0
# wt_county_above_thresh                                    105.0
# wt_county_hw_count                                      21240.0
# wt_county_hw_perc                                     81.267218
# unwt_county_ind_counts                                      276
#
#                                                        44796635
# INDNAICS                                                   5112
# PERWT                                                     105.0
# INCWAGE                                                  200000
# NAICS Code                                                 5112
# County                                                San Diego
# Rural/Urban_x_x_x                                         Urban
# CDI Regions_x_x_x                            San Diego-Imperial
# Regional COL                                              51652
# Rural/Urban COL                                           79472
# County COL                                                79472
# Regional Rural/Urban COL                                  79472
# LMID Industry Title                         software publishers
# Area Type                                                County
# Date                                                    12/1/19
# Seasonally Adjusted                                           N
# Current Employment                                         5400
# Main_EDD                                            information
# Main_Code                                                   500
# Sub_1                     publishing industries except internet
# Sub_1_Code                                                  511
# Sub_2                                       software publishers
# Sub_2_Code                                                 511b
# Sub_3                                       software publishers
# Sub_3_Code                                                 511b
# Sub_4                                       software publishers
# Sub_4_Code                                                 511b
# Above CA Threshold                                            1
# wt_ind_counts                                           26136.0
# wt_CA_above_thresh                                        105.0
# wt_CA_high_wage_count                                   21240.0
# wt_CA_high_wage_perc                                  81.267218
# unwt_ind_counts                                             276
# above_comm_thresh                                             1
# Rural/Urban_y                                             Urban
# wt_comm_ind_counts                                      26136.0
# wt_comm_above_thresh                                      105.0
# Rural/Urban_x_y                                           Urban
# wt_comm_high_wage_count                                 21240.0
# wt_comm_high_wage_perc                                81.267218
# Rural/Urban_x_x_y                                         Urban
# unwt_comm_ind_counts_x                                      276
# above_region_thresh                                           1
# CDI Regions_y                                San Diego-Imperial
# wt_reg_ind_counts                                       26136.0
# wt_reg_above_thresh                                       105.0
# CDI Regions_x_y                              San Diego-Imperial
# wt_reg_high_wage_count                                  21804.0
# wt_reg_high_wage_perc                                 83.425161
# CDI Regions_x_x_y                            San Diego-Imperial
# unwt_comm_ind_counts_y                                      276
# above_regcomm_thresh                                          1
# wt_regcomm_ind_counts                                   26136.0
# wt_regcomm_above_thresh                                   105.0
# wt_regcomm_hw_count                                     21240.0
# wt_regcomm_hw_perc                                    81.267218
# unwt_regcomm_ind_counts                                     276
# above_county_thresh                                           1
# wt_county_ind_counts                                    26136.0
# wt_county_above_thresh                                    105.0
# wt_county_hw_count                                      21240.0
# wt_county_hw_perc                                     81.267218
# unwt_county_ind_counts                                      276

# %%
def ca_ipums_edd_filter(df, county, NAICS, n):
    df = df.loc[df['County'] == county].copy()
    if len(df) == 0:
        return "County not valid"
    df = df.loc[df['INDNAICS'] == NAICS].copy()
    if len(df) == 0:
        return "NAICS Code not valid"
    df = df.drop_duplicates(subset='INDNAICS').reset_index().iloc[:,1:]
    if df['unwt_county_ind_counts'].values[0] >= n:
        return f"County: {county}, Geographical level used: County, High wage percentage: {df['wt_county_hw_perc'].values[0]}"
    elif df['unwt_regcomm_ind_counts'].values[0] >= n:
        return f"County: {county}, Geographical level used: Regional Rural/Urban, High wage percentage: {df['wt_regcomm_hw_perc'].values[0]}"
    elif df['unwt_reg_ind_counts'].values[0] >= n:
        return f"County: {county}, Geographical level used: Regional, High wage percentage: {df['wt_reg_high_wage_perc'].values[0]}"
    elif df['unwt_comm_ind_counts'].values[0] >= n:
        return f"County: {county}, Geographical level used: Rural/Urban, High wage percentage: {df['wt_comm_high_wage_perc'].values[0]}"
    elif df['unwt_ind_counts'].values[0] >= n:
        return f"County: {county}, Geographical level used: State, High wage percentage: {df['wt_CA_high_wage_perc'].values[0]}"
    else:
        return "Not enough records available to satisfy sample size request"

# %%
def check_sample_size(n, df, geo_level: str):
    df_new = df.copy()
    # creating state level counts
    df_new = add_to_state_df(df_new)
    
    # creating rural/urban level counts
    df_new = add_to_community_df(df_new)
    
    # creating regional level counts
    df_new = add_to_region_df(df_new)
    
    # creating regional rural/urban level counts
    df_new = add_to_regioncomm_df(df_new)
    
    # creating county level counts
    df_new = add_to_county_df(df_new)
    
    # geo_level conditions
    if geo_level == 'state':
        # drop everything besides state
        df_new = df_new[df_new.unwt_ind_counts > n]
    elif geo_level == 'rural/urban':
        # drop everything besides state, rural/urban
        df_new = df_new[df_new.unwt_comm_ind_counts > n]
    elif geo_level == 'regional':
        # ...
        df_new = df_new[df_new.unwt_reg_ind_counts > n]
    elif geo_level == 'regional rural/urban':
        df_new = df_new[df_new.unwt_regcomm_ind_counts > n]
    elif geo_level == 'county':
        df_new = df_new[df_new.unwt_county_ind_counts > n]
    else:
        return 'Invalid Geographical Level'
    
#     antijoin = df[~df['Industry Title'].isin(df_new['Industry Title'])]
#     antijoin = antijoin['Industry Title'].unique()
    return df_new, antijoin

# %%
# for a given N, what industries are missing in california that appear in the EDD data?
# go off EDD data for list of industries
# do EDD merge before sample size check - merge on parsed codes
# double check EDD parsing - accounting for duplicate industries properly?
# add EDD industry title/code columns, and geo level counts for each, differentiate from ipums industry

# %%
ca_ipums_new, ca_ipums_aj = check_sample_size(50, ca_ipums, 'rural/urban')

# %%
ca_ipums_new
# Out:
#        INDNAICS  PERWT  INCWAGE NAICS Code  \
# 0          4853   21.0    23100       4853
# 1          4853   21.0    23100       4853
# 2          4853   21.0    23100       4853
# 3          4853   21.0    23100       4853
# 4          4853   11.0    28000       4853
# ...         ...    ...      ...        ...
# 488571     3211  102.0    28800       3211
# 488572     3113  558.0     5300       3113
# 488573     3113  244.0     5300       3113
# 488574     4247  117.0    50000       4247
# 488575    42491  148.0    40000      42491
#
#                                            Industry Title  Parsed_Code  \
# 0                              Taxi and limousine service          485
# 1                              Taxi and limousine service          485
# 2                              Taxi and limousine service          485
# 3                              Taxi and limousine service          485
# 4                              Taxi and limousine service          485
# ...                                                   ...          ...
# 488571                     Sawmills and wood preservation          321
# 488572                   Sugar and confectionery products          311
# 488573                   Sugar and confectionery products          311
# 488574  Petroleum and petroleum products merchant whol...          424
# 488575                 Farm supplies merchant wholesalers          424
#
#              County Rural/Urban    CDI Regions  Regional COL  ...  \
# 0       Los Angeles       Urban    Los Angeles         80216  ...
# 1       Los Angeles       Urban    Los Angeles         80216  ...
# 2       Los Angeles       Urban    Los Angeles         80216  ...
# 3       Los Angeles       Urban    Los Angeles         80216  ...
# 4       Los Angeles       Urban    Los Angeles         80216  ...
# ...             ...         ...            ...           ...  ...
# 488571     Humboldt       Rural  Redwood Coast         58625  ...
# 488572     Humboldt       Rural  Redwood Coast         58625  ...
# 488573     Humboldt       Rural  Redwood Coast         58625  ...
# 488574     Humboldt       Rural  Redwood Coast         58625  ...
# 488575     Humboldt       Rural  Redwood Coast         58625  ...
#
#         wt_regcomm_above_thresh  wt_regcomm_hw_count  wt_regcomm_hw_perc  \
# 0                           0.0               9408.0            3.046524
# 1                           0.0               9408.0            3.046524
# 2                           0.0               9408.0            3.046524
# 3                           0.0               9408.0            3.046524
# 4                           0.0               9408.0            3.046524
# ...                         ...                  ...                 ...
# 488571                      0.0               1470.0           15.291792
# 488572                      0.0               1512.0           10.114389
# 488573                      0.0               1512.0           10.114389
# 488574                      0.0               4594.0           30.886110
# 488575                      0.0               2744.0           31.977625
#
#         unwt_regcomm_ind_counts  above_county_thresh  wt_county_ind_counts  \
# 0                          2786                    0              308811.0
# 1                          2786                    0              308811.0
# 2                          2786                    0              308811.0
# 3                          2786                    0              308811.0
# 4                          2786                    0              308811.0
# ...                         ...                  ...                   ...
# 488571                       95                    0                9613.0
# 488572                      145                    0               14949.0
# 488573                      145                    0               14949.0
# 488574                      169                    0               14874.0
# 488575                      115                    0                8581.0
#
#         wt_county_above_thresh  wt_county_hw_count  wt_county_hw_perc  \
# 0                          0.0              9206.0           2.981111
# 1                          0.0              9206.0           2.981111
# 2                          0.0              9206.0           2.981111
# 3                          0.0              9206.0           2.981111
# 4                          0.0              9206.0           2.981111
# ...                        ...                 ...                ...
# 488571                     0.0              1470.0          15.291792
# 488572                     0.0              1512.0          10.114389
# 488573                     0.0              1512.0          10.114389
# 488574                     0.0              4705.0          31.632379
# 488575                     0.0              2744.0          31.977625
#
#         unwt_county_ind_counts
# 0                         2786
# 1                         2786
# 2                         2786
# 3                         2786
# 4                         2786
# ...                        ...
# 488571                      95
# 488572                     145
# 488573                     145
# 488574                     169
# 488575                     115
#
# [487979 rows x 43 columns]

# %%
ca_ipums_aj, len(ca_ipums_aj)
# Out:
# (array(['Carpet and rug mills',
#         'Veneer, plywood, and engineered wood products',
#         'Military reserves or national guard', 'Agricultural chemicals',
#         'Pottery, ceramics, and plumbing fixture manufacturing',
#         'Prefabricated wood buildings and mobile homes', 'Logging',
#         'Clay building material and refractories manufacturing',
#         'Knitting fabric mills, and apparel knitting mills',
#         'Farm product raw materials, merchant wholesalers ', 'Ordnance',
#         'Agricultural implements', 'Railroad rolling stock manufacturing',
#         'Pipeline transportation', 'Tobacco', 'Coal mining',
#         'Miscellaneous petroleum and coal products', 'Metal ore mining'],
#        dtype=object),
#  18)

# %%
ns = [5, 10, 15, 20, 30, 40, 50, 60, 70]
levels = ['state', 'rural/urban', 'regional', 'regional rural/urban', 'county']

# %%
for level in levels:
    for n in ns:
        ca_ipums_new, ca_ipums_aj = check_sample_size(n, ca_ipums, level)
        print(f'Level)
        print(ca_ipums_aj, len(ca_ipums_aj))
