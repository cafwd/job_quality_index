# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
import warnings
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ### Loading Data

# %%
edd = pd.read_csv('data/Current_EDD_0917.csv')

# %%
high_wage_ca_wt = pd.read_feather('data/high_wage_ca_wt.fea')

# %%
regions_high_wage_merged = pd.read_feather('data/regions_high_wage_merged.fea')

# %%
edd_2019 = edd.loc[edd['Year'] == 2019].copy()

# %%
ca_edd_2019 = edd_2019.loc[edd_2019['Area Name'] == 'California'].copy()

# %% [markdown]
# ### Cleaning Data

# %%
def normalize_titles(col):
    col = col.astype(str)
    col = col.str.strip()
    col = col.str.lower()
    col = col.str.replace('&', 'and')
    col = col.apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
    return col

# %%
ca_edd_2019['Industry Title'] = normalize_titles(ca_edd_2019['Industry Title'])

# %%
high_wage_ca_wt['Industry Title'] = normalize_titles(high_wage_ca_wt['Industry Title'])

# %%
edd_merged = pd.merge(ca_edd_2019, high_wage_ca_wt, on = 'Industry Title', how = 'right')

# %%
print(len(edd_merged), len(edd), len(high_wage_ca_wt))
# Out:
# 787 1308590 269

# %%
edd_merged
# Out:
#     Area Type   Area Name    Year     Month        Date  Series Code  \
# 0         NaN         NaN     NaN       NaN         NaN          NaN
# 1         NaN         NaN     NaN       NaN         NaN          NaN
# 2       State  California  2019.0   January  01/01/2019   50511200.0
# 3       State  California  2019.0  February  02/01/2019   50511200.0
# 4       State  California  2019.0     March  03/01/2019   50511200.0
# ..        ...         ...     ...       ...         ...          ...
# 782       NaN         NaN     NaN       NaN         NaN          NaN
# 783       NaN         NaN     NaN       NaN         NaN          NaN
# 784       NaN         NaN     NaN       NaN         NaN          NaN
# 785       NaN         NaN     NaN       NaN         NaN          NaN
# 786       NaN         NaN     NaN       NaN         NaN          NaN
#
#                                         Industry Title Seasonally Adjusted  \
# 0                                          coal mining                 NaN
# 1                                              tobacco                 NaN
# 2                                  software publishers                   N
# 3                                  software publishers                   N
# 4                                  software publishers                   N
# ..                                                 ...                 ...
# 782                                           florists                 NaN
# 783                       book stores and news dealers                 NaN
# 784           sewing needlework and piece goods stores                 NaN
# 785                                 private households                 NaN
# 786  unemployed with no work experience in past 5 y...                 NaN
#
#      Current Employment  unweighted_ind_counts  wt_ind_counts  \
# 0                   NaN                      3          713.0
# 1                   NaN                      2           62.0
# 2               92700.0                    405        40383.0
# 3               93800.0                    405        40383.0
# 4               94500.0                    405        40383.0
# ..                  ...                    ...            ...
# 782                 NaN                    172        18010.0
# 783                 NaN                    162        15111.0
# 784                 NaN                     83         8011.0
# 785                 NaN                   1529       180264.0
# 786                 NaN                   2013       240244.0
#
#      wt_CA_high_wage_count  wt_CA_high_wage_perc
# 0                    713.0            100.000000
# 1                     55.0             88.709677
# 2                  34271.0             84.864918
# 3                  34271.0             84.864918
# 4                  34271.0             84.864918
# ..                     ...                   ...
# 782                  921.0              5.113826
# 783                  697.0              4.612534
# 784                  316.0              3.944576
# 785                 6958.0              3.859894
# 786                    0.0              0.000000
#
# [787 rows x 13 columns]

# %%
edd_merged = edd_merged[['Industry Title', 'Seasonally Adjusted', 'Current Employment', 'unweighted_ind_counts',
                        'wt_ind_counts', 'wt_CA_high_wage_count', 'wt_CA_high_wage_perc']]

# %%
edd_merged
# Out:
#                                         Industry Title Seasonally Adjusted  \
# 0                                          coal mining                 NaN
# 1                                              tobacco                 NaN
# 2                                  software publishers                   N
# 3                                  software publishers                   N
# 4                                  software publishers                   N
# ..                                                 ...                 ...
# 782                                           florists                 NaN
# 783                       book stores and news dealers                 NaN
# 784           sewing needlework and piece goods stores                 NaN
# 785                                 private households                 NaN
# 786  unemployed with no work experience in past 5 y...                 NaN
#
#      Current Employment  unweighted_ind_counts  wt_ind_counts  \
# 0                   NaN                      3          713.0
# 1                   NaN                      2           62.0
# 2               92700.0                    405        40383.0
# 3               93800.0                    405        40383.0
# 4               94500.0                    405        40383.0
# ..                  ...                    ...            ...
# 782                 NaN                    172        18010.0
# 783                 NaN                    162        15111.0
# 784                 NaN                     83         8011.0
# 785                 NaN                   1529       180264.0
# 786                 NaN                   2013       240244.0
#
#      wt_CA_high_wage_count  wt_CA_high_wage_perc
# 0                    713.0            100.000000
# 1                     55.0             88.709677
# 2                  34271.0             84.864918
# 3                  34271.0             84.864918
# 4                  34271.0             84.864918
# ..                     ...                   ...
# 782                  921.0              5.113826
# 783                  697.0              4.612534
# 784                  316.0              3.944576
# 785                 6958.0              3.859894
# 786                    0.0              0.000000
#
# [787 rows x 7 columns]

# %%
print(f'''TOTAL ROWS: {len(edd_merged)}''')
print('\n')
for column in edd_merged.columns.values:
    total = len(edd_merged)
    nulls = edd_merged[column].isna().sum()
    percentage = (nulls / total) * 100
    print(f'''{column}: {nulls} null values, {percentage:.2f}%''')
# Out:
# TOTAL ROWS: 787
#
#
# Industry Title: 0 null values, 0.00%
# Seasonally Adjusted: 223 null values, 28.34%
# Current Employment: 223 null values, 28.34%
# wt_ind_counts: 0 null values, 0.00%
# wt_CA_high_wage_count: 0 null values, 0.00%
# wt_CA_high_wage_perc: 0 null values, 0.00%

# %%
for column in edd_merged.columns.values:
    print(f'''{column}: {len(edd_merged[column].unique())} unique values''')
# Out:
# Industry Title: 269 unique values
# Seasonally Adjusted: 3 unique values
# Current Employment: 421 unique values
# wt_ind_counts: 269 unique values
# wt_CA_high_wage_count: 269 unique values
# wt_CA_high_wage_perc: 269 unique values

# %% [markdown]
# ### EDD Analysis

# %%
edd_merged['weighted_sample_perc'] = (edd_merged['wt_ind_counts'] / edd_merged['Current Employment']) * 100
edd_merged['unweighted_sample_perc'] = (edd_merged['unweighted_ind_counts'] / edd_merged['Current Employment']) * 100

# %%
edd_merged
# Out:
#                                         Industry Title Seasonally Adjusted  \
# 0                                          coal mining                 NaN
# 1                                              tobacco                 NaN
# 2                                  software publishers                   N
# 3                                  software publishers                   N
# 4                                  software publishers                   N
# ..                                                 ...                 ...
# 782                                           florists                 NaN
# 783                       book stores and news dealers                 NaN
# 784           sewing needlework and piece goods stores                 NaN
# 785                                 private households                 NaN
# 786  unemployed with no work experience in past 5 y...                 NaN
#
#      Current Employment  unweighted_ind_counts  wt_ind_counts  \
# 0                   NaN                      3          713.0
# 1                   NaN                      2           62.0
# 2               92700.0                    405        40383.0
# 3               93800.0                    405        40383.0
# 4               94500.0                    405        40383.0
# ..                  ...                    ...            ...
# 782                 NaN                    172        18010.0
# 783                 NaN                    162        15111.0
# 784                 NaN                     83         8011.0
# 785                 NaN                   1529       180264.0
# 786                 NaN                   2013       240244.0
#
#      wt_CA_high_wage_count  wt_CA_high_wage_perc  weighted_sample  \
# 0                    713.0            100.000000              NaN
# 1                     55.0             88.709677              NaN
# 2                  34271.0             84.864918        43.563107
# 3                  34271.0             84.864918        43.052239
# 4                  34271.0             84.864918        42.733333
# ..                     ...                   ...              ...
# 782                  921.0              5.113826              NaN
# 783                  697.0              4.612534              NaN
# 784                  316.0              3.944576              NaN
# 785                 6958.0              3.859894              NaN
# 786                    0.0              0.000000              NaN
#
#      unweighted_sample  weighted_sample_perc  unweighted_sample_perc
# 0                  NaN                   NaN                     NaN
# 1                  NaN                   NaN                     NaN
# 2             0.436893             43.563107                0.436893
# 3             0.431770             43.052239                0.431770
# 4             0.428571             42.733333                0.428571
# ..                 ...                   ...                     ...
# 782                NaN                   NaN                     NaN
# 783                NaN                   NaN                     NaN
# 784                NaN                   NaN                     NaN
# 785                NaN                   NaN                     NaN
# 786                NaN                   NaN                     NaN
#
# [787 rows x 11 columns]
